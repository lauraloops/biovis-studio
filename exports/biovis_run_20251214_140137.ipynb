# %% [markdown]
# # BioVis Studio Run
#
# Exported at 20251214_140137
#
# Session keys: outliers_univariate, X, raw_df, prep_complete, viz_figure, outlier_flag, outlier_action, metadata, prep_meta, cluster_labels, working_df

# %% [markdown]
# ## Data (head)

# %%
import pandas as pd
from io import StringIO
csv = '''UMAP1,UMAP2
11.902885,4.737922
-10.149738,-9.757822
-13.312086,-14.063012
-13.663692,-14.125747
-13.326636,-13.6880455
11.9325695,4.806271
11.748565,4.954813
-9.945556,-11.658023
-13.502813,-13.843255
11.879274,3.914416
-2.6577334,4.295698
11.535373,5.3187733
11.226366,5.444277
-2.9359512,4.1888194
10.971435,5.2873654
-2.558067,4.429201
-9.115344,-10.891071
-10.345376,-11.9800005
-13.25198,-13.915977
-13.274061,-13.72669
'''
df = pd.read_csv(StringIO(csv))
df
