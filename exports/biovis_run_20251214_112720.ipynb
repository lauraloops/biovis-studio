# %% [markdown]
# # BioVis Studio Run
#
# Exported at 20251214_112720
#
# Session keys: feature_cols, outlier_action, outlier_flag, working_df, metadata_cols, outliers_univariate, X, prep_meta, raw_df, prep_complete, metadata, viz_figure

# %% [markdown]
# ## Data (head)

# %%
import pandas as pd
from io import StringIO
csv = '''PC1,PC2
1.9897301280836428,0.45338414888520606
3.7251672655781074,0.793064645576324
2.7418837759700936,-0.6918610305287166
-0.16301647284563128,-1.6121636607191887
-1.649517526495786,0.5366533824122833
-1.7175700515123817,-0.04936099857918481
2.561080053592789,1.039538615880771
-0.6252729722327667,1.298876430087691
0.9498419072523718,0.42280867063498273
2.328801048933448,-0.9814469072847133
-0.49017465592764015,-0.6442057090468146
0.26819836740549774,1.5669694404672898
1.4537208871855516,0.2765502145154856
-2.3508230394683554,-0.14490299824442265
-0.811324663103934,0.9867872382743754
-1.092511563662566,-0.2379726568785011
-0.6363303055661987,-1.5751535116784172
-1.0595211272842076,0.06600109503975096
-1.456009789918497,0.8385545987726855
-1.75104698503347,0.13847665506300127
'''
df = pd.read_csv(StringIO(csv))
df
